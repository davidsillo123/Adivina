# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
X_0 = 0 # inicia el caminador
elements = [1, -1] # Águila o Sol
probabilities = [0.5, 0.5] # P(Aguila) = 0.5 , P(Sol) = 0.5
delta_X = np.random.choice(elements, 15, p=probabilities)

y = np.ones(len(np.cumsum(delta_X)))
plt.plot(np.cumsum(delta_X), y)

# %%
plt.plot(np.cumsum(delta_X))
plt.xlabel("Tiempo")
plt.ylabel("Distancia")

# %%
def walker():
    global x,y
    eleccion = random.randint(0,3)
    if eleccion == 0:
        x+=1
    elif eleccion == 1:
        x-=1
    elif eleccion == 2:
        y+=1
    else:
        y-=1
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    x += random.randint(-1,1)
    y += random.randint(-1,1)
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")

# %% [markdown]
# # mejorando el código

# %%
X_0 = np.array([[0],[0]])
delta_X = np.random.uniform(-1,1,(2,100))

X = np.concatenate((X_0,np.cumsum(delta_X,axis=1)),axis=1)
rw= plt.plot(X[0],X[1],"ro-")

# %%
def walker():
    global x,y
    eleccion = random.randint(0,1)
    if eleccion < 0.40:
        x+=1
    elif eleccion < 0.60:
        x-=1
    elif eleccion < 0.8:
        y+=1
    else:
        y-=1
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    x += np.random.normal(0,2000)
    y += random.gauss(0,2000)
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    r = random.uniform(0,1)
    if r < 0.01: # un 1% de probabilidad de tomar un paso grande
        x += np.random.normal(0,2000)
        y += random.gauss(0,2000) 
    else:
        x += np.random.normal(0,1)
        y += random.gauss(0,1)
    return [x,y]

x = 0 # inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],"bo-")
plt.plot(Pos[0,-1],Pos[1,-1],"ro-")

# %%
# %%timeit

inicio=np.array([ [0],[0] ])

elements = np.array([ [1,-1,0,0] , [0,0,1,-1] ])
probabilities = [0,4,0,2,0,2,0,2]

pasos = elements[:,np.random.choice(elements.shape[1],100,p= probabilities)]
pasos = np.concatenate( (inicios,pasos),axis=1)

Pos = np.cumsum(pasos, axis=1)
plt.plot(Pos[0,:],Pos[1,:],'bo-')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-559b76b81714> in <module>()
# ----> 1 get_ipython().run_cell_magic('timeit', '', "\ninicio=np.array([ [0],[0] ])\n\nelements = np.array([ [1,-1,0,0] , [0,0,1,-1] ])\nprobabilities = [0,4,0,2,0,2,0,2]\n\npasos = elements[:,np.random.choice(elements.shape[1],100,p= probabilities)]\npasos = np.concatenate( (inicios,pasos),axis=1)\n\nPos = np.cumsum(pasos, axis=1)\nplt.plot(Pos[0,:],Pos[1,:],'bo-')")
#
# /Users/davidallende/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-58> in timeit(self, line, cell)
#
# /Users/davidallende/anaconda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/davidallende/anaconda/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#    1047             number = 1
#    1048             for _ in range(1, 10):
# -> 1049                 time_number = timer.timeit(number)
#    1050                 worst_tuning = max(worst_tuning, time_number / number)
#    1051                 if time_number >= 0.2:
#
# /Users/davidallende/anaconda/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# mtrand.pyx in mtrand.RandomState.choice (numpy/random/mtrand/mtrand.c:17641)()
#
# ValueError: a and p must have same size
