# %% [markdown]
# $x(t)= A cos(w_0 t) + B sin(w_0 t)$

# %% [markdown]
# $$x(t) = A \cos(\omega_0t) + B \sin(\omega_0t)$$
# $$ \dot{x}(t) = \omega_0[-A \sin(\omega_0 t ) + B \cos(\omega_0t)] $$

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# $[\int\limits_{\vert x-x_0 \vert < X_0}\Phi(x)] $

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.arange(0,10,1)
y = x**2
plt.plot(x,y)

# %%
import matplotlib as mpl 
label_size = 14
mpl.rcParams['xtick.labelsize'] = label_size
mpl.rcParams['ytick.labelsize'] = label_size

# %%
t = np.linspace(0,50,100)
plt.figure(figsize = (7, 4))
plt.plot(t, .5*np.cos(.5 *t) + .1 * np.sin(.5*t), '-', lw = 1, ms=4,
        label = '$x(t)$')
plt.plot(t, .5*.1*np.cos(.5 *t) - .5*.5 * np.sin(.5*t), 'ro-', lw = 1, ms=4,
        label = r'$\dot{x(t)}$')
plt.xlabel('$t$', fontsize=20)
plt.show()

# %%
t = np.linspace(0,50,100)
plt.figure(figsize = (7, 4))
plt.plot(t, .5*np.cos(.5 *t) + .1 * np.sin(.5*t), '-', lw = 6, ms=5,
        label = '$x(t)$')
plt.plot(t, .5*.1*np.cos(.5 *t) - .5*.5 * np.sin(.5*t), 'bv-', lw = 2, ms=3,
        label = r'$\dot{x(t)}$')
plt.xlabel('$t$', fontsize=20)
plt.show()

# %%
plt.figure(figsize = (7, 4))
plt.scatter(t, .5*np.cos(.5 *t) + .1 * np.sin(.5*t),  lw = 0, c= "red",
        label = '$x(t)$')
plt.scatter(t, .5*.1*np.cos(.5 *t) - .5*.5 * np.sin(.5*t),  lw = 0, c= "b",
        label = r'$\dot{x(t)}$')

plt.xlabel('$t$', fontsize=20)
plt.legend(loc= 'best')
plt.show()

# %%
frecuencias = np.array([.1,.2,.5,.6])
plt.figure(figsize = (7,4))
for f in frecuencias:
    plt.plot(t, .5 * np.cos(f*t) + .1 * np.sin(f * t), '*-')
plt.xlabel('$t$', fontsize = 16)
plt.ylabel('$x(t)$', fontsize = 16)
plt.title('oscilaciones', fontsize = 16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ac51cb65880e> in <module>()
# ----> 1 frecuencias = np.array([.1,.2,.5,.6])
#       2 plt.figure(figsize = (7,4))
#       3 for f in frecuencias:
#       4     plt.plot(t, .5 * np.cos(f*t) + .1 * np.sin(f * t), '*-')
#       5 plt.xlabel('$t$', fontsize = 16)
#
# NameError: name 'np' is not defined
